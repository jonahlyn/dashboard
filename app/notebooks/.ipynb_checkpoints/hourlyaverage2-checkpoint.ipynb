# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
# Load configuration
from config import DATABASE_URI

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

# %%
# Create a database connection
conn = create_engine(DATABASE_URI, echo=False)
# Query the database
query = "SELECT date, vehicles FROM data"
df = pd.read_sql(query, conn)

# %%
df = df.groupby(pd.Grouper(key='date', freq='5min')).sum()
df = df.reset_index() #.dropna()
df['interval'] = df['date'].dt.strftime('%H%M').astype('int64')

# Ensure no intervals end in anything other than 0 or 5
for name, gdf in dff.groupby('interval'):
    print(name)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# 55
# 100
# 105
# 110
# 115
# 120
# 125
# 130
# 135
# 140
# 145
# 150
# 155
# 200
# 205
# 210
# 215
# 220
# 225
# 230
# 235
# 240
# 245
# 250
# 255
# 300
# 305
# 310
# 315
# 320
# 325
# 330
# 335
# 340
# 345
# 350
# 355
# 400
# 405
# 410
# 415
# 420
# 425
# 430
# 435
# 440
# 445
# 450
# 455
# 500
# 505
# 510
# 515
# 520
# 525
# 530
# 535
# 540
# 545
# 550
# 555
# 600
# 605
# 610
# 615
# 620
# 625
# 630
# 635
# 640
# 645
# 650
# 655
# 700
# 705
# 710
# 715
# 720
# 725
# 730
# 735
# 740
# 745
# 750
# 755
# 800
# 805
# 810
# 815
# 820
# 825
# 830
# 835
# 840
# 845
# 850
# 855
# 900
# 905
# 910
# 915
# 920
# 925
# 930
# 935
# 940
# 945
# 950
# 955
# 1000
# 1005
# 1010
# 1015
# 1020
# 1025
# 1030
# 1035
# 1040
# 1045
# 1050
# 1055
# 1100
# 1105
# 1110
# 1115
# 1120
# 1125
# 1130
# 1135
# 1140
# 1145
# 1150
# 1155
# 1200
# 1205
# 1210
# 1215
# 1220
# 1225
# 1230
# 1235
# 1240
# 1245
# 1250
# 1255
# 1300
# 1305
# 1310
# 1315
# 1320
# 1325
# ...

# %%
dff[dff['vehicles'] == dff['vehicles'].max()]
# Out:
#                     date  vehicles  interval
# 452  2019-01-02 13:40:00        12      1340
# 2733 2019-01-10 11:45:00        12      1145
# 3307 2019-01-12 11:35:00        12      1135

# %%
dff[dff['interval'] == 1340]['vehicles']
# Out:
# 164       1
# 452      12
# 740       1
# 1028      1
# 1316      0
# 1604      1
# 1892      6
# 2180      2
# 2468      2
# 2756      4
# 3044      2
# 3332      2
# 3620      0
# 3908      0
# 4196      0
# 4484      0
# 4772      0
# 5060      0
# 5348      0
# 5636      0
# 5924      1
# 6212      2
# 6500      3
# 6788      4
# 7076      1
# 7364      1
# 7652      1
# 7940      3
# 8228      1
# 8516      3
#          ..
# 15428     2
# 15716     1
# 16004     5
# 16292     2
# 16580     0
# 16868     1
# 17156     2
# 17444     0
# 17732     0
# 18020     2
# 18308     1
# 18596     0
# 18884     0
# 19172     0
# 19460     0
# 19748     0
# 20036     4
# 20324     2
# 20612     2
# 20900     0
# 21188     2
# 21476     0
# 21764     1
# 22052     2
# 22340     5
# 22628     3
# 22916     1
# 23204     1
# 23492     2
# 23780     0
# Name: vehicles, Length: 83, dtype: int64

# %%
dff[dff['interval'] == 1340]['vehicles'].mean()
# Out:
# 1.3734939759036144

# %%
grouped = dff.groupby('interval', as_index = False).agg({'vehicles': np.average})

data = [go.Scatter(
            x=grouped['interval'],
            y=grouped['vehicles'],
            mode='lines',
            # hoverinfo = 'text',
            # text = dff.apply(get_hover_text, axis=1),
            # fill='tonexty',
            fill='tozeroy'
        )]

py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jonahlyn/75.embed" height="525px" width="100%"></iframe>
