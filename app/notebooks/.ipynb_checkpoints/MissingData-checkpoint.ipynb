# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
# Load configuration
from config import DATABASE_URI

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# Create a database connection
conn = create_engine(DATABASE_URI, echo=False)
# Query the database
query = "SELECT date, vehicles FROM data where date between '2019-01-06' and '2019-01-07'"
df = pd.read_sql(query, conn)

# Create a full series of datetime values
idx = pd.date_range('2019-01-06', '2019-01-07', freq='5min')
df = df.groupby(pd.Grouper(key='date', freq='5min')).sum()
df.index = pd.DatetimeIndex(df.index)
df = df.reindex(idx, fill_value=0)
df
# Out:
#                      vehicles
# 2019-01-06 00:00:00         0
# 2019-01-06 00:05:00         0
# 2019-01-06 00:10:00         0
# 2019-01-06 00:15:00         0
# 2019-01-06 00:20:00         0
# 2019-01-06 00:25:00         0
# 2019-01-06 00:30:00         1
# 2019-01-06 00:35:00         0
# 2019-01-06 00:40:00         0
# 2019-01-06 00:45:00         0
# 2019-01-06 00:50:00         0
# 2019-01-06 00:55:00         0
# 2019-01-06 01:00:00         0
# 2019-01-06 01:05:00         0
# 2019-01-06 01:10:00         0
# 2019-01-06 01:15:00         0
# 2019-01-06 01:20:00         0
# 2019-01-06 01:25:00         0
# 2019-01-06 01:30:00         0
# 2019-01-06 01:35:00         0
# 2019-01-06 01:40:00         0
# 2019-01-06 01:45:00         0
# 2019-01-06 01:50:00         0
# 2019-01-06 01:55:00         0
# 2019-01-06 02:00:00         0
# 2019-01-06 02:05:00         0
# 2019-01-06 02:10:00         0
# 2019-01-06 02:15:00         0
# 2019-01-06 02:20:00         0
# 2019-01-06 02:25:00         0
# ...                       ...
# 2019-01-06 21:35:00         0
# 2019-01-06 21:40:00         0
# 2019-01-06 21:45:00         0
# 2019-01-06 21:50:00         0
# 2019-01-06 21:55:00         0
# 2019-01-06 22:00:00         0
# 2019-01-06 22:05:00         0
# 2019-01-06 22:10:00         0
# 2019-01-06 22:15:00         1
# 2019-01-06 22:20:00         0
# 2019-01-06 22:25:00         0
# 2019-01-06 22:30:00         0
# 2019-01-06 22:35:00         0
# 2019-01-06 22:40:00         0
# 2019-01-06 22:45:00         0
# 2019-01-06 22:50:00         0
# 2019-01-06 22:55:00         0
# 2019-01-06 23:00:00         0
# 2019-01-06 23:05:00         0
# 2019-01-06 23:10:00         0
# 2019-01-06 23:15:00         0
# 2019-01-06 23:20:00         0
# 2019-01-06 23:25:00         0
# 2019-01-06 23:30:00         1
# 2019-01-06 23:35:00         0
# 2019-01-06 23:40:00         0
# 2019-01-06 23:45:00         0
# 2019-01-06 23:50:00         0
# 2019-01-06 23:55:00         0
# 2019-01-07 00:00:00         0
#
# [289 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f6babb54becb> in <module>
# ----> 1 df.asfreq(freq='5min', fill_value=0)
#       2 df.shape
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/generic.py in asfreq(self, freq, method, how, normalize, fill_value)
#    7729         from pandas.core.resample import asfreq
#    7730         return asfreq(self, freq, method=method, how=how, normalize=normalize,
# -> 7731                       fill_value=fill_value)
#    7732
#    7733     def at_time(self, time, asof=False, axis=None):
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/resample.py in asfreq(obj, freq, method, how, normalize, fill_value)
#    1760         dti = date_range(obj.index[0], obj.index[-1], freq=freq)
#    1761         dti.name = obj.index.name
# -> 1762         new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    1763         if normalize:
#    1764             new_obj.index = new_obj.index.normalize()
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3739         if index is not None:
#    3740             frame = frame._reindex_index(index, method, copy, level,
# -> 3741                                          fill_value, limit, tolerance)
#    3742
#    3743         return frame
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3750         return self._reindex_with_indexers({0: [new_index, indexer]},
#    3751                                            copy=copy, fill_value=fill_value,
# -> 3752                                            allow_dups=False)
#    3753
#    3754     def _reindex_columns(self, new_columns, method, copy, level,
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# ~/.local/share/virtualenvs/app--rR5NwLK/lib/python3.6/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3085         # trying to reindex on an axis with duplicates
#    3086         if not self.is_unique and len(indexer):
# -> 3087             raise ValueError("cannot reindex from a duplicate axis")
#    3088
#    3089     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
df['date'][df['date'].dt.hour % 3 == 0][df['date'].dt.minute == 0]
# Out:
# 21    2019-01-06 03:00:00
# 57    2019-01-06 06:00:00
# 93    2019-01-06 09:00:00
# 129   2019-01-06 12:00:00
# 165   2019-01-06 15:00:00
# 201   2019-01-06 18:00:00
# 237   2019-01-06 21:00:00
# 273   2019-01-07 00:00:00
# 274   2019-01-07 00:00:00
# Name: date, dtype: datetime64[ns]
